# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import dataOf12 as d


fig, ax = plt.subplots()

## 4*19*19
x=np.zeros(19)
data=np.zeros(19)
l=6 ## l point to the webframe height = 1200+l*200

for m in range(19):
    i=m
    j=l*19
    k=19*19
    x[m]=d.dispDataOfUpperRight[i+j+k][2]
    data[m] = -d.dispDataOfUpperRight[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
    
ax.plot(x, data,label='D_1')

for m in range(19):
    i=m
    j=l*19
    k=19*19
    x[m]=d.dispDataOfDownRight[i+j+k][2]
    data[m] = d.dispDataOfDownRight[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]

ax.plot(x, data,label='D_2')

for m in range(19):
    i=m
    j=l*19
    k=19*19
    x[m]=d.dispDataOfDownLeft[i+j+k][2]
    data[m] = -d.dispDataOfDownLeft[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
ax.plot(x, data,label='D_3')

for m in range(19):
    i=m
    j=l*19
    k=19*19
    x[m]=d.dispDataOfUpperLeft[i+j+k][2]
    data[m] = d.dispDataOfUpperLeft[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
ax.plot(x, data,label='D_4')



ax.set_xlabel('Heightness of the Longitudinal Stringers (mm)')
ax.set_ylabel('Displacement(mm)')
plt.title("Displacement (U3) of the Four Measuring Points")
plt.legend()
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import dataOf12 as d


fig, ax = plt.subplots()

## 4*19*19
x=np.zeros(19)
data=np.zeros(19)
l=6 ## l point to stiffness = 300+l*50

for m in range(19):
    i=m*19
    j=l
    k=19*19
    x[m]=d.dispDataOfUpperRight[i+j+k][1]
    data[m] = -d.dispDataOfUpperRight[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
ax.plot(x, data,label='D_1')

for m in range(19):
    i=m*19
    j=l
    k=19*19
    x[m]=d.dispDataOfDownRight[i+j+k][1]
    data[m] = d.dispDataOfDownRight[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
ax.plot(x, data,label='D_2')

for m in range(19):
    i=m*19
    j=l
    k=19*19
    x[m]=d.dispDataOfDownLeft[i+j+k][1]
    data[m] = -d.dispDataOfDownLeft[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
ax.plot(x, data,label='D_3')

for m in range(19):
    i=m*19
    j=l
    k=19*19
    x[m]=d.dispDataOfUpperLeft[i+j+k][1]
    data[m] = d.dispDataOfUpperLeft[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
ax.plot(x, data,label='D_4')



ax.set_xlabel('Heightness of the Transverse Beams (mm)')
ax.set_ylabel('Displacement(mm)')
plt.title("Displacement (U3) of the Four Measuring Points")
plt.legend()
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import dataOf12 as d


fig, ax = plt.subplots()

## 4*19*19
x=np.zeros(19)
data=np.zeros(19)
for l in range(5): ## l -> stiffness
    for m in range(19): ## m->webframe
        i=m*19
        j=l*3
        k=19*19 ## thickness = 10
    
        x[m]=d.dispDataOfUpperRight[i+j+k][1]
        data[m] = d.dispDataOfDownRight[i+j+k][3]-d.dispDataOfUpperRight[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
    ax.plot(x, data,label='H_s'+'='+strd.dispDataOfDownRight[i+j+k][2])

ax.set_xlabel('Heightness of the Transverse Beams (mm)')
ax.set_ylabel('Displacement(mm)')
plt.title("Displacement (U3) D_2 - D_1")
plt.legend()
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import dataOf12 as d


fig, ax = plt.subplots()

## 4*19*19
x=np.zeros(19)
data=np.zeros(19)
for l in range(5): ## l -> web
    for m in range(19): ## m->stiff
        i=m
        j=l*19*3
        k=19*19 ## thickness = 10
    
        x[m]=d.dispDataOfUpperRight[i+j+k][2]
        data[m] = d.dispDataOfDownRight[i+j+k][3]-d.dispDataOfUpperRight[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
    ax.plot(x, data,label='H_b'+'='+str(d.dispDataOfUpperRight[i+j+k][1]))

ax.set_xlabel('Heightness of the Longitudinal Stringers (mm)')
ax.set_ylabel('Displacement(mm)')
plt.title("Displacement (U3) D_2 - D_1")
plt.legend()
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import dataOf12 as d


fig, ax = plt.subplots()

## 4*19*19
x=np.zeros(19)
data=np.zeros(19)
for n in range(4):
    for l in range(1): ## l -> web
        for m in range(19): ## m->stiff
            i=m
            j=l*19*3
            k=n*19*19 ## thickness = 10

            x[m]=d.dispDataOfUpperRight[i+j+k][2]
            data[m] = d.dispDataOfDownRight[i+j+k][3]-d.dispDataOfUpperRight[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
        ax.plot(x, data,label=str(d.dispDataOfUpperRight[i+j+k][0]))

ax.set_xlabel('Heightness of the Longitudinal Stringers (mm)')
ax.set_ylabel('Displacement(mm)')
plt.title("Displacement (U3) D_2-D_1")
plt.legend()
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import dataOf12 as d


fig, ax = plt.subplots()

## 4*19*19
x=np.zeros(19)
data=np.zeros(19)
for n in range(4):
    for l in range(1): ## l -> web
        for m in range(19): ## m->stiff
            i=m*19
            j=l*3
            k=n*19*19 ## thickness = 10

            x[m]=d.dispDataOfUpperRight[i+j+k][1]
            data[m] = d.dispDataOfDownRight[i+j+k][3]-d.dispDataOfUpperRight[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
        ax.plot(x, data,label=str(d.dispDataOfUpperRight[i+j+k][0]))

ax.set_xlabel('Heightness of the Transverse Beams (mm)')
ax.set_ylabel('Displacement(mm)')
plt.title("Displacement (U3) D_2-D_1")
plt.legend()
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import dataOf12 as d


fig, ax = plt.subplots()

## 4*19*19
x=np.zeros(19)
data=np.zeros(19)
l=6 ## l point to stiffness = 300+l*50

for m in range(19):
    i=m*19
    j=l
    k=19*19
    x[m]=d.dispDataOfUpperRight[i+j+k][1]
    data[m] = -d.dispDataOfUpperRight[i+j+k][3]-d.dispDataOfDownRight[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
ax.plot(x, data,label='D_1-D_2')


for m in range(19):
    i=m*19
    j=l
    k=19*19
    x[m]=d.dispDataOfDownLeft[i+j+k][1]
    data[m] = -d.dispDataOfDownLeft[i+j+k][3]-d.dispDataOfUpperLeft[i+j+k][3] #-dispDataOfUpperRight[yLine*15+i][2]
ax.plot(x, data,label='D_3-D_4')




ax.set_xlabel('Heightness of the Transverse Beams (mm)')
ax.set_ylabel('Displacement(mm)')
plt.title("Displacement (U3) of the Four Measuring Points")
plt.legend()
plt.show()
